# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("vacancies.csv")
# Out:
# C:\Users\ostan\AppData\Local\Temp\ipykernel_29460\1145290737.py:1: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("vacancies.csv")

# %%
df
# Out:
#                                                       name  \
# 0                            SAP R/3 functional consultant
# 1                            Broadcast encryption engineer
# 2                          Embedded OS engineering manager
# 3            Coordinator on Intellectual Property Projects
# 4                         Outsourcing Projects Coordinator
# ...                                                    ...
# 6332707  Ведущий специалист по сопровождению SIEM платф...
# 6332708                                    PHP-программист
# 6332709                                    Motion designer
# 6332710                                Дизайнер интерьеров
# 6332711                                           Директор
#
#                                                 key_skills  salary_from  \
# 0                                                      NaN          NaN
# 1                                                      NaN          NaN
# 2                                                      NaN          NaN
# 3                                                      NaN          NaN
# 4                                                      NaN          NaN
# ...                                                    ...          ...
# 6332707   SIEM\nPython\nLinux\nИнформационная безопасность          NaN
# 6332708  MySQL\nPHP\nPostgreSQL\nHTML\nJavaScript\njQue...          NaN
# 6332709  Adobe After Effect\nОбработка видео\nАнимация\...        400.0
# 6332710  3D Моделирование\nпунктуальность\nArchiCAD\nSk...          NaN
# 6332711  Организаторские навыки\nДеловая коммуникация\n...     200000.0
#
#          salary_to salary_currency        area_name              published_at
# 0              NaN             NaN           Москва  2003-01-24T21:30:49+0300
# 1           2000.0             USD      Южная Корея  2003-01-31T18:24:11+0300
# 2           2000.0             USD           Москва  2003-01-31T18:25:43+0300
# 3              NaN             NaN           Москва  2003-02-12T10:40:50+0300
# 4              NaN             NaN           Москва  2003-02-14T16:31:06+0300
# ...            ...             ...              ...                       ...
# 6332707   300000.0             RUR           Москва  2023-12-09T20:35:54+0300
# 6332708        NaN             NaN           Гомель  2023-12-09T20:48:22+0300
# 6332709     2000.0             EUR  Санкт-Петербург  2023-12-09T21:34:51+0300
# 6332710        NaN             NaN           Тамбов  2023-12-09T21:47:33+0300
# 6332711   300000.0             KZT          Шымкент  2023-12-09T21:52:50+0300
#
# [6332712 rows x 7 columns]

# %%
df[df['year-month'] == '2023-05']
# Out:
#                                                       name  \
# 5905773                              Middle .Net Developer
# 5905774                              Junior .Net Developer
# 5905775                              Junior .Net Developer
# 5905776                              Senior .Net Developer
# 5905777                              Senior .Net Developer
# ...                                                    ...
# 5964943  Senior Full Stack Engineer (Laravel & JavaScript)
# 5964950                         Senior/Middle Data Analyst
# 5964952                            Консультант 1С (стажер)
# 5964961                                     Программист 1С
# 5964965                           Vue.js / PHP разработчик
#
#                                                 key_skills  salary_from  \
# 5905773                         C#\n.NET Framework\nMS SQL       1500.0
# 5905774                         C#\n.NET Framework\nMS SQL       1000.0
# 5905775                         C#\n.NET Framework\nMS SQL       1000.0
# 5905776                         C#\n.NET Framework\nMS SQL       2000.0
# 5905777                         C#\n.NET Framework\nMS SQL       2000.0
# ...                                                    ...          ...
# 5964943                  JavaScript\nGit\nVanilla\nLaravel       3000.0
# 5964950  Data Analysis\nPython\nSQL\nA/B тесты\nАнализ ...       3500.0
# 5964952  1С: Бухгалтерия\n1С: Управление Торговлей\nРаб...      25000.0
# 5964961                                                NaN     250000.0
# 5964965  Vue\nJavaScript\nSPA\nLaravel\nPHP\nООП\nSQL\n...     100000.0
#
#          salary_to salary_currency        area_name              published_at  \
# 5905773     2300.0             USD          Ташкент  2023-05-01T00:00:54+0300
# 5905774     1000.0             USD           Астана  2023-05-01T00:03:46+0300
# 5905775     1000.0             USD          Ташкент  2023-05-01T00:04:10+0300
# 5905776     3000.0             USD           Астана  2023-05-01T00:08:51+0300
# 5905777     3000.0             USD          Ташкент  2023-05-01T00:09:25+0300
# ...            ...             ...              ...                       ...
# 5964943     5000.0             USD           Москва  2023-05-31T22:32:29+0300
# 5964950     4300.0             EUR           Москва  2023-05-31T22:44:29+0300
# 5964952    50000.0             RUR  Нижний Новгород  2023-05-31T22:47:10+0300
# 5964961   250000.0             RUR           Москва  2023-05-31T23:08:43+0300
# 5964965   150000.0             RUR      Севастополь  2023-05-31T23:54:39+0300
#
#          salary_mean  year year-month
# 5905773    152967.67  2023    2023-05
# 5905774     80509.30  2023    2023-05
# 5905775     80509.30  2023    2023-05
# 5905776    201273.25  2023    2023-05
# 5905777    201273.25  2023    2023-05
# ...              ...   ...        ...
# 5964943    322037.20  2023    2023-05
# 5964950    344647.68  2023    2023-05
# 5964952     37500.00  2023    2023-05
# 5964961    250000.00  2023    2023-05
# 5964965    125000.00  2023    2023-05
#
# [25910 rows x 10 columns]

# %%
df.head()
# Out:
#                                             name key_skills  salary_from  \
# 0                  SAP R/3 functional consultant        NaN          NaN
# 1                  Broadcast encryption engineer        NaN          NaN
# 2                Embedded OS engineering manager        NaN          NaN
# 3  Coordinator on Intellectual Property Projects        NaN          NaN
# 4               Outsourcing Projects Coordinator        NaN          NaN
#
#    salary_to salary_currency    area_name              published_at
# 0        NaN             NaN       Москва  2003-01-24T21:30:49+0300
# 1     2000.0             USD  Южная Корея  2003-01-31T18:24:11+0300
# 2     2000.0             USD       Москва  2003-01-31T18:25:43+0300
# 3        NaN             NaN       Москва  2003-02-12T10:40:50+0300
# 4        NaN             NaN       Москва  2003-02-14T16:31:06+0300

# %%
df.describe()
# Out:
#        salary_from  salary_to  salary_mean
# count          0.0        0.0          0.0
# mean           NaN        NaN          NaN
# std            NaN        NaN          NaN
# min            NaN        NaN          NaN
# 25%            NaN        NaN          NaN
# 50%            NaN        NaN          NaN
# 75%            NaN        NaN          NaN
# max            NaN        NaN          NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6332712 entries, 0 to 6332711
# Data columns (total 7 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   name             object
#  1   key_skills       object
#  2   salary_from      float64
#  3   salary_to        float64
#  4   salary_currency  object
#  5   area_name        object
#  6   published_at     object
# dtypes: float64(2), object(5)
# memory usage: 338.2+ MB

# %%
df['year-month']
# Out:
# 1          2003-01
# 2          2003-01
# 10         2003-04
# 11         2003-04
# 12         2003-05
#             ...
# 6332703    2023-12
# 6332704    2023-12
# 6332707    2023-12
# 6332709    2023-12
# 6332711    2023-12
# Name: year-month, Length: 3266501, dtype: object

# %%
df.dropna(subset=['salary_currency'],inplace=True)

# %%
df['year'].unique()
# Out:
# array(['2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010',
#        '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018',
#        '2019', '2020', '2021', '2022', '2023'], dtype=object)

# %%
df.loc[(df['salary_to'].isnull()), 'salary_to'] = df['salary_from']
df.loc[(df['salary_from'].isnull()), 'salary_from'] = df['salary_to']

# %%
df.insert(7, "salary_mean", (df['salary_from'] + df['salary_to']) / 2, True)

# %%
df_cur = pd.read_csv("valutes.csv")

# %%
df_cur
# Out:
#         date       BYR      USD      EUR       KZT      UAH      AZN  \
# 0    2003-01  0.016425  31.7844  33.2719  0.203925  5.94190      NaN
# 1    2003-02  0.016256  31.8345  34.4290  0.205576  5.94182      NaN
# 2    2003-03  0.015989  31.5729  33.9409  0.208194  5.89454      NaN
# 3    2003-04  0.015696  31.3801  33.9815  0.206202  5.85471      NaN
# 4    2003-05  0.015331  31.1021  34.5513  0.204875  5.77205      NaN
# ..       ...       ...      ...      ...       ...      ...      ...
# 241  2023-02       NaN  70.5174  76.3004  0.153325  1.90963  41.4808
# 242  2023-03       NaN  74.8932  79.5134  0.166748  2.03132  44.0548
# 243  2023-04       NaN  77.3233  84.1116  0.172577  2.09349  45.4843
# 244  2023-05       NaN  80.5093  88.3712  0.176474  2.18067  47.3584
# 245  2023-06       NaN  80.9942  86.5009  0.181163  2.19394  47.6436
#
#           KGS       UZS      GEL
# 0         NaN       NaN      NaN
# 1         NaN       NaN      NaN
# 2         NaN       NaN      NaN
# 3         NaN       NaN      NaN
# 4         NaN       NaN      NaN
# ..        ...       ...      ...
# 241  0.818542  0.006240  26.7010
# 242  0.856706  0.006616  28.5069
# 243  0.884504  0.006763  30.1997
# 244  0.919896  0.007068  32.2153
# 245  0.924697  0.007101  31.2490
#
# [246 rows x 10 columns]

# %%
def cur_to_rub(time, cur, salary):
    if cur == 'RUR':
        return salary
    if time in df_cur['date'].to_list():
        return salary * df_cur[cur][df_cur['date']== time].iloc[0]
    else: return salary

# %%
df.insert(8, "year", df.apply(lambda row: row.published_at.split('-')[0], axis=1), True)

# %%
df.insert(9, "year-month", df.apply(lambda row: '-'.join(row.published_at.split('-')[:2]), axis=1), True)

# %%
df = df[df.salary_mean <= 5000000]

# %%
df = df[df['year-month'] <= '2023-06']

# %%
df['salary_mean'] = df.apply(lambda row: cur_to_rub(row['year-month'],
                                                    row['salary_currency'], row['salary_mean']),axis=1)
# Out:
# C:\Users\ostan\AppData\Local\Temp\ipykernel_29460\130038989.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['salary_mean'] = df.apply(lambda row: cur_to_rub(row['year-month'],

# %%
df
# Out:
#                                                   name  \
# 1                        Broadcast encryption engineer
# 2                      Embedded OS engineering manager
# 10       Менеджер по продвижению программных продуктов
# 11                                Технический писатель
# 12                                     Бизнес-аналитик
# ...                                                ...
# 6022717   Специалист технической поддержки/ IT инженер
# 6022718              Программист микроконтроллеров (C)
# 6022719                                 Моушн-дизайнер
# 6022722   Специалист по работе с AI / контент-менеджер
# 6022723                          Руководитель проектов
#
#                                                 key_skills  salary_from  \
# 1                                                      NaN       2000.0
# 2                                                      NaN       2000.0
# 10                                                     NaN       1000.0
# 11                                                     NaN        300.0
# 12                                                     NaN       1200.0
# ...                                                    ...          ...
# 6022717  Настройка ПО\nзнания AD\nАдминистрирование сер...      70000.0
# 6022718               Микроконтроллеры\nЖелание учиться\nC     160000.0
# 6022719                                                NaN      35000.0
# 6022722  Английский язык\nПользователь ПК\nГрамотная ре...      30000.0
# 6022723  Грамотная речь\nУверенный пользователь ПК\nРаб...      40000.0
#
#          salary_to salary_currency        area_name              published_at  \
# 1           2000.0             USD      Южная Корея  2003-01-31T18:24:11+0300
# 2           2000.0             USD           Москва  2003-01-31T18:25:43+0300
# 10          1000.0             USD           Москва  2003-04-01T18:28:37+0400
# 11           300.0             USD           Москва  2003-04-01T18:35:22+0400
# 12          1200.0             USD           Москва  2003-05-14T16:18:16+0400
# ...            ...             ...              ...                       ...
# 6022717    70000.0             RUR           Москва  2023-06-30T22:48:40+0300
# 6022718   160000.0             RUR  Санкт-Петербург  2023-06-30T22:51:41+0300
# 6022719    55000.0             RUR           Калуга  2023-06-30T23:07:06+0300
# 6022722    30000.0             RUR  Санкт-Петербург  2023-06-30T23:38:07+0300
# 6022723    40000.0             RUR       Красноярск  2023-06-30T23:51:05+0300
#
#          salary_mean  year year-month
# 1           63568.80  2003    2003-01
# 2           63568.80  2003    2003-01
# 10          31380.10  2003    2003-04
# 11           9414.03  2003    2003-04
# 12          37322.52  2003    2003-05
# ...              ...   ...        ...
# 6022717     70000.00  2023    2023-06
# 6022718    160000.00  2023    2023-06
# 6022719     45000.00  2023    2023-06
# 6022722     30000.00  2023    2023-06
# 6022723     40000.00  2023    2023-06
#
# [3132751 rows x 10 columns]

# %%
df_group_year = df.groupby(by="year")

# %%
df_group_year

# %%
years = [str(x+1) for x in range(2002,2023)]

# %%
year_salary = {}
for year in years:
    year_salary[year] = df_group_year.get_group(year)['salary_mean'].mean()

# %%
df_group_year.get_group('2005')['salary_mean']
# Out:
# 9816      19424.09
# 9824     110994.80
# 9827      41623.05
# 9829      41623.05
# 9830      49947.66
#            ...
# 25832     28779.20
# 25833     28779.20
# 25835     21584.40
# 25836     86337.60
# 25837     25901.28
# Name: salary_mean, Length: 9363, dtype: float64

# %%
year_salary
# Out:
# {'2003': 41304.95041859813,
#  '2004': 42967.52186096714,
#  '2005': 44939.20745186925,
#  '2006': 41317.91754572798,
#  '2007': 44449.49173313794,
#  '2008': 48411.22144454465,
#  '2009': 44811.747280171905,
#  '2010': 44657.898453498696,
#  '2011': 46448.52379689614,
#  '2012': 47854.640423434335,
#  '2013': 49086.25650779257,
#  '2014': 48552.18105872143,
#  '2015': 51198.26262991256,
#  '2016': 57347.493811722285,
#  '2017': 60336.05967322839,
#  '2018': 65527.21205536,
#  '2019': 69946.02267297672,
#  '2020': 73089.81741000823,
#  '2021': 83365.0724144516,
#  '2022': 92238.27683392876,
#  '2023': 94597.86607513938}

# %%
year_salary
# Out:
# {'2003': 41304.95041859813,
#  '2004': 42967.52186096714,
#  '2005': 75516.58993167788,
#  '2006': 41317.91754572798,
#  '2007': 44449.49173313794,
#  '2008': 48411.22144454465,
#  '2009': 44811.747280171905,
#  '2010': 44657.898453498696,
#  '2011': 46448.52379689614,
#  '2012': 47969.24510060916,
#  '2013': 53542.00004683564,
#  '2014': 49077.03917491995,
#  '2015': 51734.739138226476,
#  '2016': 61305.709055171115,
#  '2017': 60364.01400764505,
#  '2018': 65581.98110691713,
#  '2019': 69938.33329095523,
#  '2020': 73111.31651559465,
#  '2021': 105412.51086555934,
#  '2022': 92382.78852420738,
#  '2023': 94554.20548006034}

# %%
df_vac = df[df["name"].str.contains("python|питон|пайтон")]

# %%
df_group_year_vac = df_vac.groupby(by="year")

# %%
year_salary_vac = {}
for year in years:
    try:
        year_salary_vac[year] = df_group_year_vac.get_group(year)['salary_mean'].mean()
    except:
        continue

# %%
year_salary_vac
# Out:
# {'2006': 34009.003333333334,
#  '2008': 47076.899999999994,
#  '2009': 65714.28571428571,
#  '2010': 53727.27272727273,
#  '2011': 70000.0,
#  '2012': 64999.94117647059,
#  '2013': 76950.17151162791,
#  '2014': 69134.61538461539,
#  '2015': 84768.70999999999,
#  '2016': 90927.60354166666,
#  '2017': 105367.94388888888,
#  '2018': 121804.88958333332,
#  '2019': 122343.61944444444,
#  '2020': 108711.88044444445,
#  '2021': 157090.4480141844,
#  '2022': 209574.92771966525,
#  '2023': 147605.46896551724}

# %%
plt.bar(year_salary.keys(),year_salary.values())
plt.xticks(rotation=60, size=8)
plt.title('Динамика зарплат по годам',size=16)
plt.show()

# %%
df_year_to_html = pd.DataFrame(list(year_salary.items ()), columns = ['Год', 'Средняя ЗП'])

# %%
df_year_to_html
# Out:
#      Год    Средняя ЗП
# 0   2003  41304.950419
# 1   2004  42967.521861
# 2   2005  44939.207452
# 3   2006  41317.917546
# 4   2007  44449.491733
# 5   2008  48411.221445
# 6   2009  44811.747280
# 7   2010  44657.898453
# 8   2011  46448.523797
# 9   2012  47854.640423
# 10  2013  49086.256508
# 11  2014  48552.181059
# 12  2015  51198.262630
# 13  2016  57347.493812
# 14  2017  60336.059673
# 15  2018  65527.212055
# 16  2019  69946.022673
# 17  2020  73089.817410
# 18  2021  83365.072414
# 19  2022  92238.276834
# 20  2023  94597.866075

# %%
df_year_to_html.to_html('year_to_html.html')

# %%
plt.bar(year_salary_vac.keys(),year_salary_vac.values())
plt.xticks(rotation=60, size=8)
plt.title('Динамика зарплат по годам для профессии python-разработчик',size=16)
plt.show()

# %%
df_year_vac_to_html = pd.DataFrame(list(year_salary_vac.items ()), columns = ['Год', 'Средняя ЗП'])

# %%
df_year_vac_to_html
# Out:
#      Год     Средняя ЗП
# 0   2006   34009.003333
# 1   2008   47076.900000
# 2   2009   65714.285714
# 3   2010   53727.272727
# 4   2011   70000.000000
# 5   2012   64999.941176
# 6   2013   76950.171512
# 7   2014   69134.615385
# 8   2015   84768.710000
# 9   2016   90927.603542
# 10  2017  105367.943889
# 11  2018  121804.889583
# 12  2019  122343.619444
# 13  2020  108711.880444
# 14  2021  157090.448014
# 15  2022  209574.927720
# 16  2023  147605.468966

# %%
df_year_vac_to_html.to_html('year_vac_to_html')

# %%
df_copy = pd.read_csv('vacancies.csv')
# Out:
# C:\Users\ostan\AppData\Local\Temp\ipykernel_29460\664475122.py:1: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_copy = pd.read_csv('vacancies.csv')

# %%
df_copy
# Out:
#                                                       name  \
# 0                            SAP R/3 functional consultant
# 1                            Broadcast encryption engineer
# 2                          Embedded OS engineering manager
# 3            Coordinator on Intellectual Property Projects
# 4                         Outsourcing Projects Coordinator
# ...                                                    ...
# 6332707  Ведущий специалист по сопровождению SIEM платф...
# 6332708                                    PHP-программист
# 6332709                                    Motion designer
# 6332710                                Дизайнер интерьеров
# 6332711                                           Директор
#
#                                                 key_skills  salary_from  \
# 0                                                      NaN          NaN
# 1                                                      NaN          NaN
# 2                                                      NaN          NaN
# 3                                                      NaN          NaN
# 4                                                      NaN          NaN
# ...                                                    ...          ...
# 6332707   SIEM\nPython\nLinux\nИнформационная безопасность          NaN
# 6332708  MySQL\nPHP\nPostgreSQL\nHTML\nJavaScript\njQue...          NaN
# 6332709  Adobe After Effect\nОбработка видео\nАнимация\...        400.0
# 6332710  3D Моделирование\nпунктуальность\nArchiCAD\nSk...          NaN
# 6332711  Организаторские навыки\nДеловая коммуникация\n...     200000.0
#
#          salary_to salary_currency        area_name              published_at
# 0              NaN             NaN           Москва  2003-01-24T21:30:49+0300
# 1           2000.0             USD      Южная Корея  2003-01-31T18:24:11+0300
# 2           2000.0             USD           Москва  2003-01-31T18:25:43+0300
# 3              NaN             NaN           Москва  2003-02-12T10:40:50+0300
# 4              NaN             NaN           Москва  2003-02-14T16:31:06+0300
# ...            ...             ...              ...                       ...
# 6332707   300000.0             RUR           Москва  2023-12-09T20:35:54+0300
# 6332708        NaN             NaN           Гомель  2023-12-09T20:48:22+0300
# 6332709     2000.0             EUR  Санкт-Петербург  2023-12-09T21:34:51+0300
# 6332710        NaN             NaN           Тамбов  2023-12-09T21:47:33+0300
# 6332711   300000.0             KZT          Шымкент  2023-12-09T21:52:50+0300
#
# [6332712 rows x 7 columns]

# %%
df_copy.insert(7, "year", df_copy.apply(lambda row: row.published_at.split('-')[0], axis=1), True)

# %%
df_copy_group_year_count = df_copy.groupby(by="year")

# %%
year_salary_count = {}
for year in years:
    try:
        year_salary_count[year] = len(df_copy_group_year_count.get_group(year))
    except:
        continue

# %%
df_year_salary_count_html = pd.DataFrame(list(year_salary_count.items ()), columns = ['Год', 'Количество'])

# %%
df_year_salary_count_html
# Out:
#      Год  Количество
# 0   2003        1983
# 1   2004        7833
# 2   2005       16022
# 3   2006       33321
# 4   2007       53562
# 5   2008       75070
# 6   2009       52889
# 7   2010       93494
# 8   2011      142458
# 9   2012      173897
# 10  2013      234019
# 11  2014      259571
# 12  2015      284763
# 13  2016      332460
# 14  2017      391464
# 15  2018      517670
# 16  2019      535956
# 17  2020      611885
# 18  2021      943151
# 19  2022      887542
# 20  2023      683702

# %%
df_year_salary_count_html.to_html('year_count_to_html.html')

# %%
plt.bar(year_salary_count.keys(),year_salary_count.values())
plt.xticks(rotation=60, size=8)
plt.title('Динамика количества вакансий по годам')
plt.show()

# %%
df_copy_vac = df_copy[df_copy["name"].str.contains("python|питон|пайтон")]

# %%
df_copy_group_year_vac_count = df_copy_vac.groupby(by="year")

# %%
year_salary_count_vac = {}
for year in years:
    try:
        year_salary_count_vac[year] = len(df_copy_group_year_vac_count.get_group(year))
    except:
        continue

# %%
df_year_salary_count_vac_html = pd.DataFrame(list(year_salary_count_vac.items ()), columns = ['Год', 'Средняя ЗП'])

# %%
df_year_salary_count_vac_html
# Out:
#      Год  Средняя ЗП
# 0   2006           3
# 1   2008           2
# 2   2009           7
# 3   2010          15
# 4   2011          23
# 5   2012          32
# 6   2013          55
# 7   2014          45
# 8   2015          62
# 9   2016          81
# 10  2017         137
# 11  2018         172
# 12  2019         170
# 13  2020         240
# 14  2021         386
# 15  2022         545
# 16  2023         401

# %%
df_year_salary_count_vac_html.to_html('year_count_vac_to_html.html')

# %%
plt.bar(year_salary_count_vac.keys(),year_salary_count_vac.values())
plt.xticks(rotation=60, size=8)
plt.title('Динамика количества вакансий по годам для python-разработчика')
plt.show()

# %%
import pretty_html_table

# %%
pretty_html_table.build_table(df_year_to_html, 'blue_light')
# Out:
# '<p><table class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th style = "background-color: #FFFFFF;font-family: Century Gothic, sans-serif;font-size: medium;color: #305496;text-align: left;border-bottom: 2px solid #305496;padding: 0px 20px 0px 0px;width: auto">Год</th>\n      <th style = "background-color: #FFFFFF;font-family: Century Gothic, sans-serif;font-size: medium;color: #305496;text-align: left;border-bottom: 2px solid #305496;padding: 0px 20px 0px 0px;width: auto">Средняя ЗП</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <td style = "background-color: #D9E1F2;font-family: Century Gothic, sans-serif;font-size: medium;text-align: left;padding: 0px 20px 0px 0px;width: auto">2003</td>\n      <td style = "background-color: #D9E1F2;font-family: Century Gothic, sans-serif;font-size: medium;text-align: left;padding: 0px 20px 0px 0px;width: auto">41304.950419</td>\n    </tr>\n    <tr>\n      <td style = "background-color: white; color: black;font-family: Century Gothic, sans-serif;font-size: medium;text-align: left;padding: 0px 20px 0px 0px;width: auto">2004</td>\n      <td style = "background-color: white; color: black;font-family: Century Gothic, sans-serif;font-size: medium;text-align: left;padding: 0px 20px 0px 0px;width: auto">42967.521861</td>\n    </tr>\n    <tr>\n      <td style = "background-color: #D9E1F2;font-family: Century Gothic, sans-serif;font-size: medium;text-align: left;padding: 0px 20px 0px 0px;width: auto">2005</td>\n      <td style = "background-color: #D9E1F2;font-family: Century Gothic, sans-serif;font-size: medium;text-align: left;padding: 0px 20px 0px 0px;width: auto">75516.589932</td>\n    </tr>\n    <tr>\n      <td style = "background-color: white; color: black;font-family: Century Gothic, sans-serif;font-size: medium;text-align: left;padding: 0px 20px 0px 0px;width: auto">2006</td>\n      <td style = "background-color: white; color: black;font-family: Century Gothic, sans-serif;font-size: medium;text-align: left;padding: 0px 20px 0px 0px;width: auto">41317.917546</td>\n    </tr>\n    <tr>\n      <td style = "background-color: #D9E1F2;font-family: Century Gothic, sans-serif;font-size: medium;text-align: left;padding: 0px 20px 0px 0px;width: auto">2007</td>\n      <td style = "background-color: #D9E1F2;font-family: Century Gothic, sans-serif;font-size: medium;text-align: left;padding: 0px 20px 0px 0px;width: auto">44449.491733</td>\n    </tr>\n    <tr>\n      <td style = "background-color: white; color: black;font-family: Century Gothic, sans-serif;font-size: medium;text-align: left;padding: 0px 20px 0px 0px;width: auto">2008</td>\n      <td style = "background-color: white; color: black;font-family: Century Gothic, sans-serif;font-size: medium;text-align: left;padding: 0px 20px 0px 0px;width: auto">48411.221445</td>\n    </tr>\n    <tr>\n      <td style = "background-color: #D9E1F2;font-family: Century Gothic, sans-serif;font-size: medium;text-align: left;padding: 0px 20px 0px 0px;width: auto">2009</td>\n      <td style = "background-color: #D9E1F2;font-family: Century Gothic, sans-serif;font-size: medium;text-align: left;padding: 0px 20px 0px 0px;width: auto">44811.74728</td>\n    </tr>\n    <tr>\n      <td style = "background-color: white; color: black;font-family: Century Gothic, sans-serif;font-size: medium;text-align: left;padding: 0px 20px 0px 0px;width: auto">2010</td>\n      <td style = "background-color: white; color: black;font-family: Century Gothic, sans-serif;font-size: medium;text-align: left;padding: 0px 20px 0px 0px;width: auto">44657.898453</td>\n    </tr>\n    <tr>\n      <td style = "background-color: #D9E1F2;font-family: Century Gothic, sans-serif;font-size: medium;text-align: left;padding: 0px 20px 0px 0px;width: auto">2011</td>\n      <td style = "background-color: #D9E1F2;font-family: Century Gothic, sans-serif;font-size: medium;text-align: left;padding: 0px 20px 0px 0px;width: auto">46448.523797</td>\n    </tr>\n    <tr>\n      <td style = "b ...

# %% [markdown]
# sqlite----

# %%
import sys
import os
sys.path.insert(0, '/pythonApplication')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[56], line 4
#       2 import os
#       3 sys.path.insert(0, '/pythonApplication')
# ----> 4 from models import SalaryVacYear
#
# ModuleNotFoundError: No module named 'models'

# %%
from models import SalaryVacYear
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 from models import SalaryVacYear
#
# ModuleNotFoundError: No module named 'models'

# %%
conn = sqlite3.connect('pythonDjango\db.sqlite3')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 conn = sqlite3.connect('pythonDjango\db.sqlite3')
#
# OperationalError: unable to open database file

# %%
cursor = conn.cursor()

# %%
conn.close()

# %%
cursor.execute('SELECT * FROM django_session')
users = cursor.fetchall()

# Выводим результаты
for user in users:
  print(user)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 cursor.execute('SELECT * FROM django_session')
#       2 users = cursor.fetchall()
#       4 # Выводим результаты
#
# OperationalError: no such table: django_session
